# %%
v1 <- c('the','cat', 'in', 'the', 'hat')

# %%
v1
# Out:
# [1] "the" "cat" "in"  "the" "hat"

# %%
unlist(strsplit(v1,","))
# Out:
# [1] "the" "cat" "in"  "the" "hat"

# %%
?round()

# %%
round(runif(n = 1000,min = 0.5,max = 6.5),0)
# Out:
#    [1] 1 3 3 1 4 1 4 3 3 1 5 6 6 5 1 1 1 6 1 6 3 1 1 1 6 5 2 3 2 3 6 2 6 6 5 1 2
#   [38] 1 4 2 5 5 4 5 4 4 4 1 1 4 4 3 3 4 6 5 5 6 5 4 2 1 6 5 6 3 1 3 1 2 2 4 3 2
#   [75] 3 2 5 4 4 2 1 1 5 2 3 1 6 2 6 3 5 4 5 1 3 5 4 5 3 6 1 3 2 1 5 1 3 1 4 3 4
#  [112] 1 2 6 2 2 3 1 1 4 1 6 4 1 3 2 1 2 2 5 3 5 5 6 5 5 4 4 3 5 1 5 6 3 3 3 5 5
#  [149] 2 2 6 3 4 4 6 5 1 2 6 1 4 2 5 3 2 5 1 2 1 3 1 2 3 3 4 3 5 1 6 2 2 5 1 2 1
#  [186] 4 2 3 5 6 4 2 6 3 3 1 1 5 2 3 5 1 1 4 2 6 2 1 5 6 2 5 4 5 2 6 2 5 1 1 4 3
#  [223] 3 1 4 4 4 2 2 1 4 6 6 6 5 2 6 3 2 4 6 4 4 6 2 4 4 5 2 6 5 2 3 1 6 6 5 4 1
#  [260] 5 2 6 5 6 6 4 1 6 3 2 5 5 6 1 3 6 2 5 1 6 6 6 1 2 4 3 2 2 6 2 6 1 6 3 2 4
#  [297] 2 2 6 3 6 3 3 6 6 3 6 6 3 2 6 1 4 6 2 1 4 4 1 6 3 2 3 6 2 1 5 2 3 2 5 4 5
#  [334] 1 5 2 3 5 2 3 1 5 5 2 3 4 2 4 4 2 3 3 4 4 3 6 2 3 2 5 1 2 6 5 3 6 6 5 2 5
#  [371] 1 5 1 1 3 5 2 6 1 5 1 1 2 3 2 4 4 1 5 5 4 5 3 4 3 3 4 5 5 1 1 1 4 3 2 4 5
#  [408] 5 3 5 1 6 2 3 4 6 3 4 1 2 5 3 5 3 1 1 5 4 4 3 3 1 3 3 6 5 4 4 6 2 3 5 4 2
# ...

# %%
roll=round(runif(n = 1000,min = 0.5,max = 6.5),0)
#sample(1:6,1000,replace=T,prob=c())

# %%
#roll
head(roll)
# Out:
# [1] 1 4 5 4 5 3

# %%
hist(roll,col='blue')
# Out:
# Plot with title "Histogram of roll"

# %%
first <- rnorm(1000,24,32)

# %%
second <- rnorm(1000,212,24)

# %%
addup <- first+second

# %%
head(addup)
#addup
# Out:
# [1] 224.7602 267.9790 259.1283 245.7204 284.7519 186.5200

# %%
summary(addup)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   126.1   209.2   234.9   236.0   265.2   377.4

# %%
sd(addup)
# Out:
# [1] 41.06546

# %%
mean(addup)
# Out:
# [1] 236.0443

# %%
hist(addup,col='gold',nclass = 50)
# Out:
# Plot with title "Histogram of addup"

# %%
plot(first,second,xlab="first vector - random vector 1",ylab="second vector - random vector 2")
# Out:
# plot without title
