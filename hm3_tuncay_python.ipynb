# %%
# income statement

import lxml
from lxml import html
import requests
import numpy as np
import pandas as pd

symbol = 'CMG'
#symbol=input("enter symbol, not case sensitive ==")

url = 'https://finance.yahoo.com/quote/' + symbol + '/financials?p=' + symbol

page = requests.get(url)
tree = html.fromstring(page.content)
table = tree.xpath('//table')
assert len(table) == 1

df = pd.read_html(lxml.etree.tostring(table[0], method='html'))[0]
df
# Out:
#                                          0                                  1  \
# 0                                  Revenue                         12/31/2018
# 1                            Total Revenue                            4864985
# 2                          Cost of Revenue                            3273962
# 3                             Gross Profit                            1591023
# 4                       Operating Expenses                 Operating Expenses
# 5                     Research Development                                  -
# 6       Selling General and Administrative                             455055
# 7                            Non Recurring                                  -
# 8                                   Others                             680031
# 9                 Total Operating Expenses                            4507878
# 10                Operating Income or Loss                             357107
# 11       Income from Continuing Operations  Income from Continuing Operations
# 12         Total Other Income/Expenses Net                             -88671
# 13      Earnings Before Interest and Taxes                             357107
# 14                        Interest Expense                                  -
# 15                       Income Before Tax                             268436
# 16                      Income Tax Expense                              91883
# 17                       Minority Interest                                  -
# 18          Net Income From Continuing Ops                             176553
# 19                    Non-recurring Events               Non-recurring Events
# 20                 Discontinued Operations                                  -
# 21                     Extraordinary Items                                  -
# 22            Effect Of Accounting Changes                                  -
# 23                             Other Items                                  -
# 24                              Net Income                         Net Income
# 25                              Net Income                             176553
# 26   Preferred Stock And Other Adjustments                                  -
# 27  Net Income Applicable To Common Shares                             176553
#
#                                     2                                  3  \
# 0                          12/31/2017                         12/31/2016
# 1                             4476412                            3904384
# 2                             3068552                            2764217
# 3                             1407860                            1140167
# 4                  Operating Expenses                 Operating Expenses
# 5                                   -                                  -
# 6                              372733                             379209
# 7                                   -                                  -
# 8                              545299                             538984
# 9                             4162273                            3845940
# 10                             314139                              58444
# 11  Income from Continuing Operations  Income from Continuing Operations
# 12                             -38396                             -19705
# 13                             314139                              58444
# 14                                  -                                  -
# 15                             275743                              38739
# 16                              99490                              15801
# 17                                  -                                  -
# 18                             176253                              22938
# 19               Non-recurring Events               Non-recurring Events
# 20                                  -                                  -
# 21                                  -                                  -
# 22                                  -                                  -
# 23                                  -                                  -
# 24                         Net Income                         Net Income
# 25                             176253                              22938
# 26                                  -                                  -
# 27                             176253                              22938
#
#                                     4
# 0                          12/31/2015
# 1                             4501223
# 2                             2811973
# 3                             1689250
# 4                  Operating Expenses
# 5                                   -
# 6                              319471
# 7                                   -
# 8                              445706
# 9                             3724440
# 10                             776783
# 11  Income from Continuing Operations
# 12                              -6916
# 13                             776783
# 14                                  -
# 15                             769867
# 16                             294265
# 17                                  -
# 18                             475602
# 19               Non-recurring Events
# 20                                  -
# 21                                  -
# 22                                  -
# 23                                  -
# 24                         Net Income
# 25                             475602
# 26                                  -
# 27                             475602

# %%
# balance sheet

import lxml
from lxml import html
import requests
import numpy as np
import pandas as pd

symbol = 'CMG'
#symbol=input("enter symbol, not case sensitive ==")

url = 'https://finance.yahoo.com/quote/' + symbol + '/balance-sheet?p=' + symbol

page = requests.get(url)
tree = html.fromstring(page.content)
table = tree.xpath('//table')
assert len(table) == 1

df = pd.read_html(lxml.etree.tostring(table[0], method='html'))[0]
df
# Out:
#                                        0                     1  \
# 0                          Period Ending            12/31/2018
# 1                         Current Assets        Current Assets
# 2              Cash And Cash Equivalents                249953
# 3                 Short Term Investments                426845
# 4                        Net Receivables                 62312
# 5                              Inventory                 21555
# 6                   Other Current Assets                     -
# 7                   Total Current Assets                814794
# 8                  Long Term Investments                     -
# 9           Property Plant and Equipment               1379254
# 10                              Goodwill                 21939
# 11                     Intangible Assets                     -
# 12              Accumulated Amortization                     -
# 13                          Other Assets                 49531
# 14      Deferred Long Term Asset Charges                     -
# 15                          Total Assets               2265518
# 16                   Current Liabilities   Current Liabilities
# 17                      Accounts Payable                113071
# 18          Short/Current Long Term Debt                     -
# 19             Other Current Liabilities                 75603
# 20             Total Current Liabilities                449990
# 21                        Long Term Debt                     -
# 22                     Other Liabilities                374189
# 23  Deferred Long Term Liability Charges                     -
# 24                     Minority Interest                     -
# 25                     Negative Goodwill                     -
# 26                     Total Liabilities                824179
# 27                  Stockholders' Equity  Stockholders' Equity
# 28         Misc. Stocks Options Warrants                     -
# 29            Redeemable Preferred Stock                     -
# 30                       Preferred Stock                     -
# 31                          Common Stock                   360
# 32                     Retained Earnings               2573617
# 33                        Treasury Stock              -2506792
# 34                       Capital Surplus               1374154
# 35              Other Stockholder Equity                 -6236
# 36              Total Stockholder Equity               1441339
# 37                   Net Tangible Assets               1419400
#
#                        2                     3                     4
# 0             12/31/2017            12/31/2016            12/31/2015
# 1         Current Assets        Current Assets        Current Assets
# 2                 184569                 87880                248005
# 3                 324382                329836                415199
# 4                  49806                 45559                 96435
# 5                  19860                 15019                 15043
# 6                      -                     -                     -
# 7                 629535                522374                814647
# 8                      -                125055                622939
# 9                1338366               1303558               1217220
# 10                 21939                 21939                 21939
# 11                     -                     -                     -
# 12                     -                     -                     -
# 13                 55852                 53177                 48321
# 14                     -                     -                     -
# 15               2045692               2026103               2725066
# 16   Current Liabilities   Current Liabilities   Current Liabilities
# 17                 82028                 78363                 85709
# 18                     -                     -                     -
# 19                 93645                 59438                 76233
# 20                323893                281793                279942
# 21                     -                     -                     -
# 22                357354                341817                314090
# 23                     -                     -                     -
# 24                     -                     -                     -
# 25                     -                     -                     -
# 26                681247                623610                597092
# 27  Stockholders' Equity  Stockholders' Equity  Stockholders' Equity
# 28                     -                     -                     -
# 29                     -                     -                     -
# 30                     -                     -                     -
# 31                   359                   358                   358
# 32               2397064               2220811               2197873
# 33              -2338068              -2057551              -1242885
# 34               1305090               1238875               1172628
# 35                 -3659                 -8162                 -8273
# 36               1364445               1402493               2127974
# 37               1342506               1380554               2106035

# %%
# cash flow

import lxml
from lxml import html
import requests
import numpy as np
import pandas as pd

symbol = 'CMG'
#symbol=input("enter symbol, not case sensitive ==")

url = 'https://finance.yahoo.com/quote/' + symbol + '/cash-flow?p=' + symbol

page = requests.get(url)
tree = html.fromstring(page.content)
table = tree.xpath('//table')
assert len(table) == 1

df = pd.read_html(lxml.etree.tostring(table[0], method='html'))[0]
df
# Out:
#                                                     0  \
# 0                                       Period Ending
# 1                                          Net Income
# 2   Operating Activities, Cash Flows Provided By o...
# 3                                        Depreciation
# 4                           Adjustments To Net Income
# 5                     Changes In Accounts Receivables
# 6                              Changes In Liabilities
# 7                              Changes In Inventories
# 8               Changes In Other Operating Activities
# 9           Total Cash Flow From Operating Activities
# 10  Investing Activities, Cash Flows Provided By o...
# 11                               Capital Expenditures
# 12                                        Investments
# 13         Other Cash flows from Investing Activities
# 14         Total Cash Flows From Investing Activities
# 15  Financing Activities, Cash Flows Provided By o...
# 16                                     Dividends Paid
# 17                             Sale Purchase of Stock
# 18                                     Net Borrowings
# 19         Other Cash Flows from Financing Activities
# 20         Total Cash Flows From Financing Activities
# 21                    Effect Of Exchange Rate Changes
# 22                Change In Cash and Cash Equivalents
#
#                                                     1  \
# 0                                          12/31/2018
# 1                                              176553
# 2   Operating Activities, Cash Flows Provided By o...
# 3                                              201979
# 4                                              138943
# 5                                               -8298
# 6                                               38909
# 7                                               -1722
# 8                                               60749
# 9                                              621552
# 10  Investing Activities, Cash Flows Provided By o...
# 11                                            -287390
# 12                                            -100188
# 13                                                  -
# 14                                            -387578
# 15  Financing Activities, Cash Flows Provided By o...
# 16                                                  -
# 17                                                  -
# 18                                                  -
# 19                                               -187
# 20                                            -166535
# 21                                              -1457
# 22                                              65982
#
#                                                     2  \
# 0                                          12/31/2017
# 1                                              176253
# 2   Operating Activities, Cash Flows Provided By o...
# 3                                              163348
# 4                                               60570
# 5                                                -140
# 6                                               15115
# 7                                               -5250
# 8                                               62493
# 9                                              468216
# 10  Investing Activities, Cash Flows Provided By o...
# 11                                            -216777
# 12                                             130199
# 13                                                  -
# 14                                             -86578
# 15  Financing Activities, Cash Flows Provided By o...
# 16                                                  -
# 17                                                  -
# 18                                                  -
# 19                                               -187
# 20                                            -285894
# 21                                               2056
# 22                                              97800
#
#                                                     3  \
# 0                                          12/31/2016
# 1                                               22938
# 2   Operating Activities, Cash Flows Provided By o...
# 3                                              146368
# 4                                               71650
# 5                                               -1923
# 6                                                1649
# 7                                                 -91
# 8                                               60229
# 9                                              355160
# 10  Investing Activities, Cash Flows Provided By o...
# 11                                            -258842
# 12                                             585648
# 13                                                  -
# 14                                             326806
# 15  Financing Activities, Cash Flows Provided By o...
# 16                                                  -
# 17                                                  -
# 18                                                  -
# 19                                               -187
# 20                                            -836283
# 21                                                110
# 22                                            -154207
#
#                                                     4
# 0                                          12/31/2015
# 1                                              475602
# 2   Operating Activities, Cash Flows Provided By o...
# 3                                              130368
# 4                                                8888
# 5                                               -3504
# 6                                               19525
# 7                                                 262
# 8                                               19419
# 9                                              683316
# 10  Investing Activities, Cash Flows Provided By o...
# 11                                            -257418
# 12                                            -206722
# 13                                                  -
# 14                                            -464140
# 15  Financing Activities, Cash Flows Provided By o...
# 16                                                  -
# 17                                                  -
# 18                                                  -
# 19                                              74235
# 20                                            -386440
# 21                                              -4196
# 22                                            -171460

# %%
import pandas as pd
import datetime
from pandas_datareader import data as web
import matplotlib.pyplot as plt

start=datetime.datetime(2010,1,1)
#end=datetime.datetime(2019,1,1)

symbol="CMG"
#symbol=input("enter symbol, not case sensitive ==")

df=web.DataReader(symbol, "yahoo", start)
#df=web.DataReader(symbol, "yahoo", start, end)
df.tail()
# Out:
#                   High         Low        Open       Close  Volume   Adj Close
# Date
# 2019-02-14  606.900024  593.799988  597.020020  604.429993  489600  604.429993
# 2019-02-15  609.289978  601.179993  606.510010  605.890015  585800  605.890015
# 2019-02-19  609.239990  599.020020  606.140015  599.460022  489500  599.460022
# 2019-02-20  600.520020  594.210022  598.409973  597.739990  383700  597.739990
# 2019-02-21  606.630005  592.729980  597.729980  601.190002  465731  601.190002

# %%
df['Adj Close'].plot()
plt.show()
